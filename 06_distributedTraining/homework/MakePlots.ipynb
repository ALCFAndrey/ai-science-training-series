# %%
import pandas as pd

df1 = pd.read_csv("metrics_1.dat", sep=" ", header=None)
df2 = pd.read_csv("metrics_2.dat", sep=" ", header=None)
df4 = pd.read_csv("metrics_4.dat", sep=" ", header=None)
df8 = pd.read_csv("metrics_8.dat", sep=" ", header=None)
#df16 = pd.read_csv("metrics_16.dat", sep=" ", header=None)

#df1.columns = ['train_acc','train_loss','valid_acc','valid_loss','time_per_epochs']

# %%
import matplotlib.pyplot as plt

fig,ax = pyplot.subplots()
ax.plot(df1.iloc[:,0],color='r',label='Train')
ax.plot(df1.iloc[:,2],color='b',label='Valid')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
fig.savefig('accuracy1.pdf')

fig,ax = pyplot.subplots()
ax.plot(df2.iloc[:,0],color='r',label='Train')
ax.plot(df2.iloc[:,2],color='b',label='Valid')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
fig.savefig('accuracy2.pdf')

fig,ax = pyplot.subplots()
ax.plot(df4.iloc[:,0],color='r',label='Train')
ax.plot(df4.iloc[:,2],color='b',label='Valid')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
fig.savefig('accuracy4.pdf')

fig,ax = pyplot.subplots()
ax.plot(df8.iloc[:,0],color='r',label='Train')
ax.plot(df8.iloc[:,2],color='b',label='Valid')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('accuracy')
fig.savefig('accuracy8.pdf')


#fig,ax = pyplot.subplots()
#ax.plot(df16.iloc[:,0],color='r',label='Train')
#ax.plot(df16.iloc[:,2],color='b',label='Valid')
#ax.legend()
#ax.set_xlabel('epochs')
#ax.set_ylabel('accuracy')
#fig.savefig('accuracy16.pdf')
